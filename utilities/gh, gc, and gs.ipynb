# %%
import os
import shutil

f = open("togds.txt", 'r')

sdir = 'data'
ddir = 'nyt'

for line in f:
    fields = line.split(',')
    guid = fields[2]
    date = fields[3]
    
    sfn = sdir+'/'+date[6:10]+'/'+date[0:2]+'/'+date[3:5]+'/'+str(guid)+'.xml'
    dfn = ddir+'/'+str(guid)+'.'+'.xml'
    shutil.copy(sfn, dfn)
    #fa = open(fn, 'r')
    #fa.close()
    

f.close()

# %%
f = open("togds.txt", 'r')

ddir = 'nyt'

for line in f:
    fields = line.split(',')
    guid = fields[2]
    date = fields[3]
    
    sfn = 'nyt'+str(guid)+'..xml'
    dfn = ddir+'/'+str(guid)+'.xml'
    if os.path.isfile(sfn):
        shutil.move(sfn, dfn)
    #fa = open(fn, 'r')
    #fa.close()
    

f.close()

# %%
from sets import Set
ftogds = open("togds.test.txt", 'r')
t = Set([])
g = Set([])
o = Set([])

for line in ftogds:
    fields = line.split(',')
    t.add(fields[0])
    o.add(fields[1])
    g.add(fields[2])
ftodgs.close()

tt = {}
gg = {}
oo = {}
   
tl = list(t)
gl = list(g)
ol = list(o)

tl.sort()
gl.sort()
ol.sort()

t = Set(tl)
g = Set(gl)
o = Set(ol)

ftogds = open("togds.test.txt", 'r')

for line in ftogds:
    fields = line.split(',')
    tt[fields[0]] = 0
    oo[fields[1]] = 0
    gg[fields[2]] = 0
ftogds.close()


ftogds = open("togds.test.txt", 'r')

for line in ftogds:
    fields = line.split(',')
    tt[fields[0]] = tt[fields[0]]+1
    oo[fields[1]] = oo[fields[1]]+1
    gg[fields[2]] = gg[fields[2]]+1
ftogds.close()

fout = open('test.t.txt', 'w')
for (k, v) in sorted(tt.iteritems(), key=lambda (k,v): (v,k), reverse=True):
    fout.write(k+','+str(v)+'\n')
fout.close
fout = open('test.g.txt', 'w')
for (k, v) in sorted(gg.iteritems(), key=lambda (k,v): (v,k), reverse=True):
    fout.write(k+','+str(v)+'\n')
fout.close
fout = open('test.o.txt', 'w')
for (k, v) in sorted(oo.iteritems(), key=lambda (k,v): (v,k), reverse=True):
    fout.write(k+','+str(v)+'\n')
fout.close



print len(t), len(o), len(g)
print len(tt), len(oo), len(oo)
# Out:
# 241 521 16337
# 241 521 521

# %%
import xml.etree.ElementTree as ET
ftodgs = open("togds.txt", 'r')

ddir = 'nyt'

for line in ftodgs:
    fields = line.split(',')
    org  = fields[1]
    guid = fields[2]
    date = fields[3]
    
    fin = 'nyt'+'/'+str(guid)+'.xml'
    fgh = 'gh'+'/'+str(guid)+'.txt'
    fgl = 'gl'+'/'+str(guid)+'.txt'
    fgc = 'gc'+'/'+str(guid)+'.txt'
    #fgs = 'gss'+'/'+str(guid)+'.txt'
    f = open(fin, 'r')
    gh = open(fgh, 'w')
    gl = open(fgl, 'w')
    gc = open(fgc, 'w')
    #gs = open(fgs, 'w')
    '''
    this is the final step, well, almost, before the merge
    three folders we go:
    1. gh: headline
    2. gl: leadning paragraph
    2. gc: content
    3. gs: sentence
    under each is a file with the same name <guid>.txt
    

    header first
    '''
    tree = ET.parse(fin)

    for headline in tree.getroot().iter('hl1'):
        gh.write(headline.text.encode('utf-8')+'\n')
    
    for block in tree.getroot().iter('block'):
        if block.get('class') == 'lead_paragraph':
            for p in block.iter('p'):
                gl.write(p.text.encode('utf-8'))
        else:
            if block.get('class') == 'full_text':
                for p in block.iter('p'):
                    gc.write(p.text.encode('utf-8'))
                    #if org.strip().lower() in p.text.strip().lower():
                        #gs.write(p.text.encode('utf-8')+'\n')
    f.close()
    gh.close()
    gl.close()
    gc.close()
    #gs.close()
    

ftogds.close()

# %%
ftogds = open('togds.txt','r')

to = Set([])

for line in ftogds:
    to.add(line.split(',')[0]+','+line.split(',')[1])
ftogds.close()
tol = list(to)
tol.sort()

fout = open('to.txt', 'w')
for i in tol:
    fout.write(i+'\n')
fout.close()

# %%
import xml.etree.ElementTree as ET

import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

fto = open("to.txt", "r")

dto = {}

for line in fto:
    fields = line.split(',')
    dto[fields[0]] = Set([])

fto.close()

fto = open("to.txt", "r")

for line in fto:
    fields = line.split(',')
    oname = fields[1].encode('utf-8').strip().lower()
    if oname.split(' ')[-1][0:2] == 'in' or oname.split(' ')[-1][0:2] == 'co':
        #cut from end to the last ' '
        oname = ' '.join(oname.split(' ')[:-1])
    dto[fields[0]].add(oname)
fto.close()
  
ftodgs = open("togds.txt", 'r')

ddir = 'nyt'

for line in ftodgs:
    fields = line.split(',')
    ticker  = fields[0]
    guid = fields[2]
    
    fin = 'nyt'+'/'+str(guid)+'.xml'
    fgs = 'gt'+'/'+str(guid)+'.txt'
    f = open(fin, 'r')
    gs = open(fgs, 'w')
    '''
    this is the final step, well, almost, before the merge
    three folders we go:
    1. gh: headline
    2. gl: leadning paragraph
    2. gc: content
    3. gs: sentence
    under each is a file with the same name <guid>.txt
    

    header first
    '''
    tree = ET.parse(fin)

    for block in tree.getroot().iter('block'):
        if block.get('class') == 'full_text':
            for p in block.iter('p'):
                done = False
                src = p.text.strip().lower()

                sentences = tokenizer.tokenize(src)
                for sentence in sentences:
                    for o in dto[ticker]:
                        if o.strip().lower() in sentence and not done:
                            gs.write(p.text.encode('utf-8')+'\n')
                            done = True
    f.close()
    gh.close()
    gl.close()
    gc.close()
    gs.close()
    

ftogds.close()

# %%
import nltk.data

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
fp = open("test.txt")
data = fp.read()
print '\n-----\n'.join(tokenizer.tokenize(data))

# %%
#import nltk
#nltk.download()
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sdir = "gssss"
ddir = "gt"

for dirName, subdirList, fileList in os.walk(sdir):
    for fn in fileList:
        fi = open(sdir+'/'+fn, "r")
        data = fi.read()
        
        fo = open(ddir+'/'+fn, "w")
    
        data = data.encode('utf-8')
        sentences = tokenizer.tokenize(data)
        
        for sentences = 
        fo.write('\n'.join(tokenizer.tokenize(data)))
        fi.close()
        fo.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-55-db4925712649> in <module>()
#      12
#      13         fo = open(ddir+'/'+fn, "w")
# ---> 14         fo.write('\n'.join(tokenizer.tokenize(data)))
#      15         fi.close()
#      16         fo.close()
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     309     it = iter(it)
#     310     prev = next(it)
# --> 311     for el in it:
#     312         yield (prev, el)
#     313         prev = el
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _slices_from_text(self, text)
#    1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
# -> 1280             if self.text_contains_sentbreak(context):
#    1281                 yield slice(last_break, match.end())
#    1282                 if match.group('next_tok'):
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in text_contains_sentbreak(self, text)
#    1323         """
#    1324         found = False # used to ignore last token
# -> 1325         for t in self._annotate_tokens(self._tokenize_words(text)):
#    1326             if found:
#    1327                 return True
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _annotate_second_pass(self, tokens)
#    1458         heuristic (4.1.2) and frequent sentence starter heuristic (4.1.3).
#    1459         """
# -> 1460         for t1, t2 in _pair_iter(tokens):
#    1461             self._second_pass_annotation(t1, t2)
#    1462             yield t1
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _annotate_first_pass(self, tokens)
#     575           - ellipsis_toks: The indices of all ellipsis marks.
#     576         """
# --> 577         for aug_tok in tokens:
#     578             self._first_pass_annotation(aug_tok)
#     579             yield aug_tok
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/punkt.pyc in _tokenize_words(self, plaintext)
#     540         """
#     541         parastart = False
# --> 542         for line in plaintext.split('\n'):
#     543             if line.strip():
#     544                 line_toks = iter(self._lang_vars.word_tokenize(line))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 6: ordinal not in range(128)

# %%
ftogds = open("togds.txt", "r")

fbig = open("big.txt",'w')

gs = {}

for line in ftogds:
    fields = line.split(',')
    g = fields[2]
    s = fields[4][:-1]
    gs[g] = s

sdir = "gt"

for dirName, subdirList, fileList in os.walk(sdir):
    for fn in fileList:
        f = open(sdir+'/'+fn)
        for line in f:
            fbig.write(gs[fn[:-4]]+'|'+line)
        f.close()

fbig.close()

# %%
import os
from sets import Set

s = Set([])

f = open("big.txt")

for i in f:
    s.add(float(i.split('|')[0]))

sl = list(s)
sl.sort()

print sl
# Out:
# [-0.440819423369, -0.428688262986, -0.396814520976, -0.376548140476, -0.375625427204, -0.325334491425, -0.313442531669, -0.304470616512, -0.303640292099, -0.302319395136, -0.301716480797, -0.288233540987, -0.280125514883, -0.26543242251, -0.262038005043, -0.261361192746, -0.258806150541, -0.257729439081, -0.250444393277, -0.249908530211, -0.24633314634, -0.244079973531, -0.243998431751, -0.241832669323, -0.238688386998, -0.228119638303, -0.225474964114, -0.224986110009, -0.224284055896, -0.222826211086, -0.214261873836, -0.212764918449, -0.206894202602, -0.206693733526, -0.204272903112, -0.203091342727, -0.201596933887, -0.201290298556, -0.20065144922, -0.200311623559, -0.200225546311, -0.195479412916, -0.194806300553, -0.192216961679, -0.192101940982, -0.191668419945, -0.191502400163, -0.191471544715, -0.190986638484, -0.189175919033, -0.188063976536, -0.186738176499, -0.18612458038, -0.184870043513, -0.183258662146, -0.183189535207, -0.182798751064, -0.18134767456, -0.179713840487, -0.178470288951, -0.177869986169, -0.175985142119, -0.17569762419, -0.175162396814, -0.173566662127, -0.172941757157, -0.170648444247, -0.169871097997, -0.167939549865, -0.167631216335, -0.166649008182, -0.165534554046, -0.1645215003, -0.164481037181, -0.164458574547, -0.163271405874, -0.162155688623, -0.160769360175, -0.159605446103, -0.159472183542, -0.159379185378, -0.159360671618, -0.15889937251, -0.158874009376, -0.158099352052, -0.157656687487, -0.15710232473, -0.156415609443, -0.156048361837, -0.154823925227, -0.154689010635, -0.15458928171, -0.153857163303, -0.153775491457, -0.152708505009, -0.151603414879, -0.151215805471, -0.150417697298, -0.150016225488, -0.14841233318, -0.148264277716, -0.146777750551, -0.146718697101, -0.1466359977, -0.146301168052, -0.146137474643, -0.145109632915, -0.144309245136, -0.144305630998, -0.144174732681, -0.144014926243, -0.143409439055, -0.143245968642, -0.142717557252, -0.142291487593, -0.141690793283, -0.141101379823, -0.141068773961, -0.140709436054, -0.138993877088, -0.138796880009, -0.138774238766, -0.138086491902, -0.137552577746, -0.137544679681, -0.137149258965, -0.1367194005, -0.136610802822, -0.136607964838, -0.135427803822, -0.135211267606, -0.13520636379, -0.134746401768, -0.134601383327, -0.134356256433, -0.134320246689, -0.134076536137, -0.133687276481, -0.133622477843, -0.133482214928, -0.133105758737, -0.131718419769, -0.131702584006, -0.131621187801, -0.131487889273, -0.131294293174, -0.131236128534, -0.130860534125, -0.130546885602, -0.130442374854, -0.129393647738, -0.129147438976, -0.129018196563, -0.128981908478, -0.128869271225, -0.128700474018, -0.128113398583, -0.128000634161, -0.127431388223, -0.127401963737, -0.127012616244, -0.126909412253, -0.126351189046, -0.126313172127, -0.126011548286, -0.125727147191, -0.124811639387, -0.12471814401, -0.12447636146, -0.124208876261, -0.123981537822, -0.123851321803, -0.123699640628, -0.123606745148, -0.123066688841, -0.122994106692, -0.122858837087, -0.122815373905, -0.122301842001, -0.122286309381, -0.122199907307, -0.121330936472, -0.121124662508, -0.121084222359, -0.120950184651, -0.120700682206, -0.120355225875, -0.120322083181, -0.120204081633, -0.120162016202, -0.120027434842, -0.119983809414, -0.119931448158, -0.119798075847, -0.119425643621, -0.119071644803, -0.118739983974, -0.118737763446, -0.118456691986, -0.118421052632, -0.118284205421, -0.118083776411, -0.118061617043, -0.11805749372, -0.118019888537, -0.117590268392, -0.117540070479, -0.11740547864, -0.117374069419, -0.117312693691, -0.117188931647, -0.117078611582, -0.11704527028, -0.117017396337, -0.116851709355, -0.116590013141, -0.116003669419, -0.115603000335, -0.115311119073, -0.115156080007, -0.115098634294, -0.114534479996, -0.113542225038, -0.113467464202, -0.113282946747, -0.113053116208, -0.113046519762, -0.112675129909, -0.112569183021, -0.112545320721, -0.112337377576, -0.112196010566, -0.112150129793, -0.112038589169, -0.111914374237, -0.111894977169, -0.111410 ...

# %%
print len(sl)

f.close()
k = 0
f = open("big.txt")
for j in f:
    k=k+1
print k
f.close()
# Out:
# 13190
# 75093

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sls = [int(x*10000000.0)/100000 for x in sl]
plt.plot(sls)
print max(sls), min(sls), sum(sls)/len(sls), sum([x == 0 for x in sls]), len(sls)
# Out:
# 49 -45 -1 1668 13190

# %%
import xml.etree.ElementTree as ET
import nltk
from sets import Set

ftogds = open("togds.txt", "r")

dgo = {}
dgs = {}

for line in ftogds:
    fields = line.split(',')
    dgo[fields[2]] = Set([])

ftogds.close()

ftogds = open("togds.txt", "r")
gnames = ['kohl','moody','st jude','accenture','adobe','aetna','agilent','akamai','allstate','altria','amazon','goldman sachs','apple','wal-mart',
    'chicago bridge & iron company','best buy','boeing','campbell','capital one','carnival','chubb','cisco','coach','comcast','conagra','dupont',
    'kodak','exxon','fifth third','ford motor','franklin templeton','garmin','goodyear','harman','hershey','honeywell','interpublic','taesa',
    'invesco funds','l-3 communications','laboratory corp of america','ford motor','loews','maestro','marriott','mastercard','merck','micron','yahoo',
    'morgan stanley','netflix','pnc bank','ralph lauren','priceline','prudential','red hat','royal caribbean','schlumberger','seagate','edison',
    'starbucks','target','walt disney','tiffany','transocean','union pacific','verizon','vornado','wells fargo','whole foods','wynn']

for line in ftogds:
    fields = line.split(',')
    oname = fields[1].encode('utf-8').strip().lower()
    guid = fields[2]
    lw = oname.split(' ')[-1]
    
    if lw[-1] == '\n':
        lw = lw[:-1]
    if lw == 'in' or lw[0:3]=='inc' or lw == 'co' or lw=='corp' or lw=='company' or lw == 'cos' or lw == 'corporation' or lw == '(co)' or lw=='ltd' or lw=='limited' or lw == '&':
        #cut from end to the last ' '
        oname = ' '.join(oname.split(' ')[:-1])

    if 'american telephone' in oname or 'at & t' in oname or 'at&t' in oname or 'at& t' in oname or 'at&amp;t' in oname or 'at &amp; t' in oname or 'at&amp; t' in oname:
        dgo[guid].add('at&t')
        dgo[guid].add('at& t')
        dgo[guid].add('at & t') 
        dgo[guid].add('at&amp; t')
        dgo[guid].add('at &amp; t')
        dgo[guid].add('at&amp;t')
        dgo[guid].add('a.t.')
    if 'coke' in oname:
        dgo[guid].add('coke')  
        dgo[guid].add('coca-cola') 
    if 'international business machines' in oname or 'ibm' in oname:
        dgo[guid].add('ibm')
        dgo[guid].add('i.b.m.')
    if 'american international group' in oname or 'aig' in oname:
        dgo[guid].add('aig')
    if 'h & r' in oname or 'h&r' in oname:
        dgo[guid].add('h&r')        
    if 'procter' in oname and 'gamble' in oname:
        dgo[guid].add('procter')
    if 'united parcel service' in oname:
        dgo[guid].add('ups')
    if 'university of southern california' in oname:
        dgo[guid].add('usc')
    if 'news corporation limited' in oname or 'newscorp' in oname or 'news corp' in oname:
        dgo[guid].add('newscorp')
        dgo[guid].add('news corp')
    
    for n in gnames:
        if n in oname:
            dgo[guid].add(n)
        
    dgo[guid].add(oname)
    sss = fields[4]
    if sss[-1]=='\n':
        sss = sss[:-1]
    dgs[guid]=str(int(float(sss)*1000000000.0)/12000000+37)
ftogds.close()

# %%
print dgo
# Out:
# {'1575981': Set(['apple', 'apple computer']), '1575982': Set(['apple', 'apple computer']), '1475833': Set(['wal-mart', 'wal-mart stores']), '1364973': Set(['micron technology', 'micron']), '0972479': Set(['waste management']), '1774045': Set(['microsoft']), '1570608': Set(['morgan stanley', 'morgan stanley dean witter &', 'united parcel service', 'union pacific', 'ups']), '1511221': Set(['marriott', 'marriott international']), '1616659': Set(['merck & company', 'merck']), '1432814': Set(['ebay']), '1273777': Set(['newscorp', 'news corporation', 'general electric', 'news corp']), '1146495': Set(['coca-cola']), '1273772': Set(['amazon', 'microsoft', 'amazon.com']), '1351060': Set(['newmont mining']), '1430913': Set(['news', 'general motors']), '1064956': Set(['i.b.m.', 'ibm', 'international business machines']), '0939417': Set(['nike']), '0896622': Set(['norfolk southern']), '1422263': Set(['i.b.m.', 'ibm', 'international business machines']), '1081053': Set(['ford motor']), '1175644': Set(['yahoo']), '1087800': Set(['interpublic group of companies', 'interpublic']), '1452753': Set(['microsoft']), '1458707': Set(['cisco', 'intel', 'cisco systems', 'microsoft']), '1210776': Set(['express scripts']), '1794321': Set(['wal-mart', 'target', 'wal-mart stores']), '1493975': Set(['newscorp', 'news corporation', 'news corp']), '0517884': Set(['at & t', 'at& t', 'at &amp; t', 'american telephone & telegraph co inc (at&t)', 'at&t', 'at&amp; t', 'at&amp;t']), '1059009': Set(['motorola']), '1234121': Set(['microsoft']), '1533133': Set(['raytheon']), '1501561': Set(['ford motor', 'general motors']), '1391945': Set(['news']), '0882588': Set(['time warner']), '0790131': Set(['at & t', 'at& t', 'at &amp; t', 'at&t', 'at&amp; t', 'at&amp;t']), '1667807': Set(['ford motor']), '1451229': Set(['monsanto', 'johnson & johnson']), '1576096': Set(['verizon communications', 'verizon']), '1645176': Set(['apple', 'apple computer']), '0618918': Set(['at & t', 'at& t', 'at &amp; t', 'american telephone & telegraph co inc (at&t)', 'at&t', 'at&amp; t', 'at&amp;t']), '1645172': Set(['apple', 'apple computer']), '1501620': Set(['morgan stanley']), '0880857': Set(['general motors']), '1184522': Set(['ford motor']), '1645178': Set(['microsoft']), '1756970': Set(['xerox']), '0927824': Set(['i.b.m.', 'ibm', 'international business machines']), '1114061': Set(['symantec']), '0927822': Set(['i.b.m.', 'ibm', 'international business machines']), '1392489': Set(['priceline', 'priceline.com']), '1450281': Set(['omnicom group']), '1026570': Set(['i.b.m.', 'ibm', 'international business machines']), '0944506': Set(['microsoft']), '1700349': Set(['texas instruments']), '0597847': Set(['at & t', 'at& t', 'at &amp; t', 'american telephone & telegraph co inc (at&t)', 'at&t', 'at&amp; t', 'at&amp;t']), '0937518': Set(['i.b.m.', 'ibm', 'international business machines']), '1849777': Set(['wal-mart', 'wal-mart stores']), '1373059': Set(["moody's investors service", 'moody']), '0997516': Set(['allstate insurance', 'allstate']), '1210512': Set(['microsoft']), '1527721': Set(['pfizer']), '1114010': Set(['motorola']), '0916447': Set(['time warner']), '1784978': Set(['general electric']), '1690611': Set(['citigroup']), '1690613': Set(['apple', 'apple computer']), '1784973': Set(['i.b.m.', 'ibm', 'international business machines']), '1691634': Set(['intel']), '1005044': Set(['coca-cola']), '1691632': Set(['interpublic group of companies', 'bank of america', 'interpublic', 'omnicom group']), '1616656': Set(['oracle']), '1219824': Set(['priceline', 'priceline.com']), '0885126': Set(['general motors']), '1361594': Set(['microsoft']), '0884004': Set(['omnicom group']), '0939066': Set(['intel', 'microsoft']), '1746743': Set(['comcast']), '0696557': Set(['at & t', 'at& t', 'at &amp; t', 'american telephone & telegraph co inc (at&t)', 'at&t', 'at&amp; t', 'at&amp;t']), '1125033': Set(['i.b.m.', 'ibm', 'international business machines']), '1051919': Set(['motorola']), '1756766': Set(['at & t',  ...

# %% [markdown]
# dddgo = dgo
# dddgs = dgs

# %%
import glob

sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
fall = open('all.txt', 'w')
fmiss = open('miss.txt','w')
#miss = Set([])
for fin in glob.glob('./nyt/*'):
    guid = fin[6:-4]

    '''
    this is the final step, well, almost, before the merge
    '''
    tree = ET.parse(fin)
    at_least_once = False
    for block in tree.getroot().iter('block'):
        if block.get('class') == 'full_text':
            for p in block.iter('p'):
                for sentence in sent_detector.tokenize(p.text.strip()):
                    found = False
                    for o in dgo[guid]:
                        if o.strip().lower() in sentence.strip().lower() and not found:
                            at_least_once = True
                            found = True
                            fall.write(dgs[guid]+'|'+sentence.encode('utf-8')+'\n')
    for abst in tree.getroot().iter('abstract'):
        #print guid
        for p in abst.iter('p'):
            if not p.text is None:
                for sentence in sent_detector.tokenize(p.text.strip()):
                    found = False
                    for o in dgo[guid]:
                        if o.strip().lower() in sentence.strip().lower() and not found:
                            at_least_once = True
                            found = True
                            fall.write(dgs[guid]+'|'+sentence.encode('utf-8')+'\n')
    for hl in tree.getroot().iter('hl1'):
        for sentence in sent_detector.tokenize(hl.text.strip()):
            found = False
            for o in dgo[guid]:
                if o.strip().lower() in sentence.strip().lower() and not found:
                    at_least_once = True
                    found = True
                    fall.write(dgs[guid]+'|'+sentence.encode('utf-8')+'\n')
        
    if not at_least_once:
        fmiss.write(guid+"|"+fin+"|"+str(dgo[guid])+'\n')
        #miss.add(dgo[guid])

fall.close()
fmiss.close()
#print miss

# %%
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
#sent_detector.tokenize(text.strip())
for line in open('tmp.txt'):
    print ;EMsent_detector.tokenize(line.strip())
# Out:
# ['To shareholders of Tyco International, the industrial products conglomerate, are deals  usually no big deal?', 'The company, which makes ADT security systems and electronic components for hospitals, cars and computers, has made four purchases worth about $4 billion in the last four months alone and has long had an acquisitive streak.']

# %%
miss = Set([])
for name in open('missed.txt'):
    miss.add(name)
lmiss = list(miss)
lmiss.sort()
print len(lmiss)

for item in lmiss:
    print item[:-1]
# Out:
# 198
# "kohl's department stores"
# "moody's investors service"
# "st jude children's research hospital (memphis)"
# '3 doors down (music group)'
# 'abyssinian baptist church (nyc)'
# 'accenture (co)'
# 'accenture (co)', 'accenture limited'
# 'accenture limited'
# 'adobe systems'
# 'aetna life insurance'
# 'aetna us healthcare'
# 'aetna'
# 'agilent technologies'
# 'akamai technologies'
# 'alain ducasse at the essex house (nyc)'
# 'allstate insurance'
# 'altria group'
# 'amazon.com'
# 'american airlines'
# 'american express'
# 'american international group', 'goldman sachs group'
# 'american telephone & telegraph co inc (at&t)'
# 'american telephone & telegraph co inc (at&t)', 'at&t bell laboratories'
# 'aon group'
# 'apple computer'
# 'apple computer', 'adobe systems'
# 'apple computer', 'best buy company'
# 'apple computer', 'international business machines'
# 'apple computer', 'microsoft'
# 'apple'
# 'archer-daniels-midland'
# 'at&t bell laboratories'
# 'at&t microelectronics'
# 'at&t'
# 'becton dickinson &'
# 'bed bath & beyond', 'wal-mart stores'
# 'best buy company'
# 'boeing'
# 'campbell soup'
# 'capital one financial'
# 'carnival cruise lines'
# 'carnival cruise lines', 'royal caribbean cruises ltd'
# 'carnival'
# 'cbs'
# 'chevrontexaco'
# 'chicago bridge & iron company nv'
# 'christian cultural center (nyc church)'
# 'chubb group'
# 'cisco systems'
# 'citigroup'
# 'coach (leather goods'
# 'coca-cola company (coke)'
# 'coca-cola company (coke)', 'news corporation limited'
# 'coca-cola company (coke)', 'the procter & gamble'
# 'comcast cablevision'
# 'comcast'
# 'conagra foods'
# 'consolidated edison co of new york'
# 'dover street market (london store)'
# 'duke energy'
# 'dupont e i nemours &'
# 'eastman kodak'
# 'eastman kodak', 'amazon.com'
# 'ebay'
# 'estee lauder'
# 'exxon mobil'
# 'exxonmobil'
# 'fifth third bancorp'
# 'ford motor'
# 'ford motor', 'general motors'
# 'franklin templeton group'
# 'franklin templeton limited duration income trust'
# 'garmin (co)', 'garmin limited'
# 'garmin (co)', 'wal-mart stores', 'garmin limited'
# 'garmin limited'
# 'general electric'
# 'general electric', 'dupont'
# 'general motors'
# 'goldman sachs &'
# 'goldman sachs &', 'goldman sachs group'
# 'goldman sachs group'
# 'goodyear tire & rubber'
# 'goodyear tire & rubber', 'ford motor'
# 'h & r block'
# 'h&r block'
# 'harman international'
# 'hershey chocolate usa'
# 'home depot'
# 'honeywell international'
# 'intercontinentalexchange'
# 'international business machines corp (ibm)'
# 'international business machines'
# 'interpublic group of companies'
# 'interpublic group of'
# 'intuit'
# 'invesco funds group'
# 'johnson & johnson'
# 'l-3 communications holdings'
# 'laboratory corp of america holdings'
# 'laboratory corp of america'
# 'lincoln-mercury division of ford motor'
# 'lockheed martin'
# 'loews hotels'
# 'loews'
# 'maestro usa'
# 'marriott hotels'
# 'marriott international'
# 'marriott marquis hotel (nyc)'
# 'mastercard international'
# 'mattel'
# 'merck & co'
# 'merck & company'
# 'merck & company', 'merck & co'
# 'merck & company', 'merck &'
# 'merck &'
# 'merck &dontsplit company'
# 'mercury division of ford motor'
# 'micron electronics'
# 'micron technology'
# 'microsoft'
# 'microsoft', 'international business machines'
# 'microsoft', 'yahoo!'
# 'morgan stanley &'
# 'morgan stanley &', 'goldman sachs group'
# 'morgan stanley &', 'morgan stanley dean witter &'
# 'morgan stanley &', 'the goldman sachs group', 'goldman sachs group', 'morgan stanley dean witter &'
# 'morgan stanley dean witter &'
# 'morgan stanley dean witter &', 'goldman sachs group'
# 'morgan stanley dean witter &', 'morgan stanley dean witter &dontsplit'
# 'morgan stanley dean witter'
# 'morgan stanley dean witter', 'citigroup', 'goldman sachs group'
# 'morgan stanley group'
# 'morgan stanley'
# 'motorola', 'apple computer'
# 'netflix.com'
# 'news corporation limited'
# 'nordstrom'
# 'pfizer'
# 'pfizer', 'international paper', 'american international group', 'verizon', 'eastman kodak'
# 'pnc bank'
# 'polo ralph lauren'
# 'priceline.com'
# 'procter & gamble'
# 'prudential corp plc'
# 'prudential insurance co of america'
# 'red hat software'
# 'royal caribbean cruise line'
# 'royal caribbean cruises ltd'
# 'sas royal hotel (copenhagen)'
# 'schlumberger ltd'
# 'schlumberger ltd', 'international business machines'
# 'seagate technology'
# 'southern california edison'
# 'southwest airlines'
# 'stanley works'
# 'starbucks coffee'
# 'target stores'
# 'target stores', 'wal-mart stores'
# 'the boeing'
# 'the goldman sachs group'
# 'the goldman sachs group', 'goldman sachs &'
# 'the goldman sachs group', 'goldman sachs group'
# 'the goldman sachs group', 'international business machines'
# 'the goldman sachs group', 'morgan stanley dean witter &'
# 'the procter & gamble'
# 'the procter &dontsplit gamble'
# 'the walt disney'
# 'tiffany &'
# 'transocean offshore'
# 'transportes aereos ejecutivos sa (taesa)'
# 'tyson foods'
# 'union pacific railroad'
# 'union pacific restaurant (nyc restaurant)'
# 'united healthcare'
# 'united parcel service of america'
# 'united parcel service'
# 'university of southern california'
# 'verizon communications'
# 'verizon'
# 'vornado realty trust'
# 'vornado realty trust', 'equity office properties trust'
# 'wal-mart stores'
# 'wal-mart stores', 'amazon.com'
# 'wal-mart stores', 'best buy company'
# 'wal-mart.com'
# 'wells fargo &'
# 'wells fargo &', 'coca-cola company (coke)'
# 'wells fargo &', 'goldman sachs group'
# 'wells fargo &dontsplit'
# 'wells fargo bank'
# 'whole foods market'
# 'wynn las vegas resort and country club (las vegas)'
# 'xerox'
# 'yahoo (co)'
# 'yahoo!'
# 'yahoo!', 'amazon.com'
# 'yahoo'
# 'yahoo.com'
